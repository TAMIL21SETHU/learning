# %%
import matplotlib.pylot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 import matplotlib.pylot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 7.2/7.2 MB 8.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 163.6/163.6 kB ? eta 0:00:00
# ...
#      ------------------------------------- 965.4/965.4 kB 10.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.5/2.5 MB 8.7 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 55.3/55.3 kB 3.0 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %% [markdown]
# # creating data

# %%
movies=['antman','captain america','avengers','ironman','spiderman']
percentage=[23,25,56,90,80]

# %%
plt.scatter(movies,percentage)

# %%
plt.plot(movies,percentage,linestyle='dashdot')

# %%
plt.plot(movies,percentage,linestyle='solid')

# %%
plt.plot(movies,percentage,linestyle='dashed')

# %%
plt.bar(movies,percentage)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.pie(percentage,labels=movies)
# Out:
# ([<matplotlib.patches.Wedge at 0x228fcf0ab00>,
# ...
#  [Text(1.06197241900273, 0.286730851631788, 'antman'),
#   Text(0.7552054911955425, 0.7997903888320362, 'captain america'),
#   Text(-0.1882522435577891, 1.0837716977276437, 'avengers'),
#   Text(-1.0586151252541474, -0.29888796660813555, 'ironman'),
#   Text(0.6688034327083829, -0.8733280989396159, 'spiderman')])

# %% [markdown]
# # sine wave

# %%
time= np.arange(0,10,0.05)

# %%
time
# Out:
# array([0.  , 0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 ,
#        0.55, 0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95, 1.  , 1.05,
#        1.1 , 1.15, 1.2 , 1.25, 1.3 , 1.35, 1.4 , 1.45, 1.5 , 1.55, 1.6 ,
#        1.65, 1.7 , 1.75, 1.8 , 1.85, 1.9 , 1.95, 2.  , 2.05, 2.1 , 2.15,
#        2.2 , 2.25, 2.3 , 2.35, 2.4 , 2.45, 2.5 , 2.55, 2.6 , 2.65, 2.7 ,
#        2.75, 2.8 , 2.85, 2.9 , 2.95, 3.  , 3.05, 3.1 , 3.15, 3.2 , 3.25,
#        3.3 , 3.35, 3.4 , 3.45, 3.5 , 3.55, 3.6 , 3.65, 3.7 , 3.75, 3.8 ,
#        3.85, 3.9 , 3.95, 4.  , 4.05, 4.1 , 4.15, 4.2 , 4.25, 4.3 , 4.35,
#        4.4 , 4.45, 4.5 , 4.55, 4.6 , 4.65, 4.7 , 4.75, 4.8 , 4.85, 4.9 ,
#        4.95, 5.  , 5.05, 5.1 , 5.15, 5.2 , 5.25, 5.3 , 5.35, 5.4 , 5.45,
#        5.5 , 5.55, 5.6 , 5.65, 5.7 , 5.75, 5.8 , 5.85, 5.9 , 5.95, 6.  ,
#        6.05, 6.1 , 6.15, 6.2 , 6.25, 6.3 , 6.35, 6.4 , 6.45, 6.5 , 6.55,
#        6.6 , 6.65, 6.7 , 6.75, 6.8 , 6.85, 6.9 , 6.95, 7.  , 7.05, 7.1 ,
# ...

# %%
amplitude=np.sin(time)
amplitude
# Out:
# array([ 0.        ,  0.04997917,  0.09983342,  0.14943813,  0.19866933,
#         0.24740396,  0.29552021,  0.34289781,  0.38941834,  0.43496553,
#         0.47942554,  0.52268723,  0.56464247,  0.60518641,  0.64421769,
#         0.68163876,  0.71735609,  0.75128041,  0.78332691,  0.8134155 ,
#         0.84147098,  0.86742323,  0.89120736,  0.91276394,  0.93203909,
#         0.94898462,  0.96355819,  0.97572336,  0.98544973,  0.99271299,
#         0.99749499,  0.99978376,  0.9995736 ,  0.99686503,  0.99166481,
#         0.98398595,  0.97384763,  0.9612752 ,  0.94630009,  0.92895972,
#         0.90929743,  0.88736237,  0.86320937,  0.83689879,  0.8084964 ,
#         0.7780732 ,  0.74570521,  0.71147335,  0.67546318,  0.6377647 ,
#         0.59847214,  0.55768372,  0.51550137,  0.47203054,  0.42737988,
#         0.38166099,  0.33498815,  0.28747801,  0.23924933,  0.19042265,
#         0.14112001,  0.09146464,  0.04158066, -0.00840725, -0.05837414,
# ...

# %%
plt.plot(time,amplitude)

# %% [markdown]
# # seaborn

# %%
pip install seaborn
# Out:
# ...
#
# ...
#      -------------------------------------- 288.2/288.2 kB 1.4 MB/s eta 0:00:00
# ...

# %%
import seaborn as sn

# %%
sn.set(style='darkgrid')

# %%
import numpy as np

# %%
random=np.random.randn(100)

# %%
random
# Out:
# array([ 0.63648538, -0.10182051,  0.49580136, -0.02690499, -0.62145087,
#         0.03755801,  1.4227791 ,  0.14803382, -0.32798165, -0.25963742,
#        -0.72520649, -0.05733451, -1.57737437, -2.34205219, -1.29482244,
#        -1.07568801,  0.89122793, -0.39140473,  0.4555789 , -0.53311039,
#        -0.22533526, -0.12896747,  0.26765777,  0.2328167 ,  0.30383372,
#        -1.41515867,  0.35469041,  0.64361841, -0.73307423,  0.13386747,
#        -0.61277923,  1.47811665,  0.44803124, -0.97738138, -0.87604262,
#         0.23727257,  0.24742775,  0.04829802,  0.48752589, -0.75799103,
#        -1.42009889, -0.53627137,  1.93795184, -0.88766718, -0.56917356,
#        -0.33045351, -1.07865807,  0.65032848, -0.58232305, -2.19160762,
#         1.22290763, -0.45674157,  0.32532737, -1.49558996, -0.795247  ,
#        -0.12414401, -0.00545012, -0.69439677, -1.04783936,  1.10226345,
#        -0.3333123 , -0.57130524,  0.26022128, -0.40250998, -1.09165359,
# ...

# %%
sn.distplot(random)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_1740\933703326.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(random)
# <AxesSubplot: ylabel='Density'>

# %%
sn.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tip=sn.load_dataset('tips')

# %%
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sn.relplot(x='total_bill',y='tip', data=tip, col="time",hue="day",style="day",kind="line")

# %% [markdown]
# # regression plot

# %%
sn.regplot(x='total_bill',y='tip',data=tip)
# Out:
# <AxesSubplot: xlabel='total_bill', ylabel='tip'>

# %%
pip install sklearn
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for sklearn: filename=sklearn-0.0.post1-py3-none-any.whl size=2936 sha256=55569d74a38f40d9cda5144da8e79a8a5faac24ae074ffcb687a9509cf5fe38c
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\c5\88\35\cc8a1e198b27a1d3d9d3f9b30090b9d5531778847835472ec4
# Successfully built sklearn
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sklearn as sk
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 import sklearn as sk
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
from sklearn.preo
