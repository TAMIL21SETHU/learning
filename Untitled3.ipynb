# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
url="https://www.royalenfield.com/in/en/motorcycles/"

# %%
bullet=requests.get(url)

# %%
bullet
# Out:
# <Response [200]>

# %%
bullet=BeautifulSoup(bullet.text)

# %%
bullet
# Out:
# <!DOCTYPE HTML>
# <html class="app__html" data-attr-pagepath="/content/royal-enfield/in/en/motorcycles">
# <head>
# <meta class="redirectPage" data-redirect="false"/>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, minimum-scale=1, maximum-scale=1, user-scalable=no" name="viewport"/>
# <meta content="Explore latest motorcycles in India from Royal Enfield including Meteor 350, Himalayan, Classic and Bullet. Book a test ride of your favourite two wheelers." name="description"/>
# <meta name="keywords"/>
# <meta content="Motorcycles | Latest Bikes in India | Two Wheelers | Royal Enfield" name="title"/>
# <title>Motorcycles | Latest Bikes in India | Two Wheelers | Royal Enfield</title>
# <link href="/content/dam/re-platform-images/favicon/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/content/dam/re-platform-images/favicon/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# ...

# %%
model=bullet.select('#teaser-list h3')

# %%
model
# Out:
# [<h3>Hunter 350</h3>,
#  <h3>Scram 411</h3>,
#  <h3>Classic 350</h3>,
#  <h3>Meteor</h3>,
#  <h3>Interceptor</h3>,
#  <h3>Continental GT</h3>,
#  <h3>Himalayan</h3>,
#  <h3>Bullet</h3>]

# %%
price=bullet.select('')
